# %%
import pandas as pd
#import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df_14 = pd.read_csv('dados/dados_isolador14.csv', sep=';', decimal=',')

# %%
df_29 = pd.read_csv('dados/dados_isolador29.csv', sep=';', decimal=',')

# %%
df_40 = pd.read_csv('dados/dados_isolador40.csv', sep=';', decimal=',')

# %%
df_15 = pd.read_csv('dados/dados_isolador15.csv', sep=';', decimal=',')

# %%
fig, axes = plt.subplots(ncols=2, figsize=(10, 2), sharex=True, sharey=True, dpi=100)
sns.distplot(df_14.corrente_fuga, ax=axes[0]);
sns.distplot(df_29.corrente_fuga, ax=axes[1]);
sns.distplot(df_40.corrente_fuga, ax=axes[2]);

# %%
fig, ax1 = plt.subplots(2, 2, figsize=(10, 6), sharey=False, dpi=100)
sns.distplot(df_14.corrente_fuga , color="dodgerblue", ax=ax1[0, 0], axlabel='Ideal')
sns.distplot(df_15.corrente_fuga , color="dodgerblue", ax=ax1[0, 1], axlabel='Ideal')
sns.distplot(df_29.corrente_fuga , color="deeppink", ax=ax1[1, 0], axlabel='Fair')
sns.distplot(df_40.corrente_fuga , color="red", ax=ax1[1, 1], axlabel='Good')
plt.tight_layout()

# %%
frames = [df_14, df_15, df_29, df_40]

# %%
df = pd.concat(frames)
df.shape
# Out:
# (161264, 7)

# %%
plt.figure(figsize=(18,8))
sns.set_style('darkgrid')
sns.distplot(df.corrente_fuga);
